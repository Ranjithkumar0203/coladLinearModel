# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranjithkumar0203/coladLinearModel/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# class Model(nn.Module):
#     def __init__(self, inputCollumsInMatric):
#         super(Model, self).__init__()
#         self.linear1 = nn.Linear(inputCollumsInMatric, 3)
#         self.relu = nn.ReLU()
#         self.linear2 = nn.Linear(3, 1)
#         self.sigmoid = nn.Sigmoid()

#     def forward(self, inputCollumsInMatric):
#       out = self.linear1(inputCollumsInMatric)
#       out = self.relu(out)
#       out = self.linear2(out)
#       out = self.sigmoid(out)
#       return out

class Model(nn.Module):
    def __init__(self, inputCollumsInMatric):
        super(Model, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(inputCollumsInMatric, 3),
            nn.ReLU(),
            nn.Linear(3, 1),
            nn.Sigmoid()
        )

    # def forward(self, inputCollumsInMatric):
    #   out = self.linear1(inputCollumsInMatric)
    #   out = self.relu(out)
    #   out = self.linear2(out)
    #   out = self.sigmoid(out)
    #   return out

    def forward(self, inputCollumsInMatric):
        out = self.network(inputCollumsInMatric)
        # out = self.linear1(inputCollumsInMatric)
        # out = self.relu(out)
        # out = self.linear2(out)
        # out = self.sigmoid(out)
        return out
# Out:
#   File "<tokenize>", line 36
#     def forward(self, inputCollumsInMatric):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
features = torch.rand(10, 5)

# %%
model = Model(features.shape[1])

# %%
model(features)

# %%
model.linear2.weight

# %%
pip install torchinfo

# %%
from torchinfo import summary
summary(model)
